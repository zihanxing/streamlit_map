# %%
import pandas as pd
import numpy as np

# %%
# read the data if the year is greater than 2019
df_all = pd.read_csv('EMDATFEMA2.csv')

# %%
df_all = df_all[df_all['Year'] > 2018]

# %%
# Save the data to a csv file
# df_all.to_csv('data_since_2019.csv', index=False)

# %%
state_name_mapping = {
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'FL': 'Florida',
    'GA': 'Georgia',
    'IA': 'Iowa',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NJ': 'New Jersey',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'PA': 'Pennsylvania',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'DE': 'Delaware',
    'KY': 'Kentucky',
    'NH': 'New Hampshire',
    'NY': 'New York',
    'OR': 'Oregon',
    'AZ': 'Arizona',
    'GU': 'Guam',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'ME': 'Maine',
    'MT': 'Montana',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'UT': 'Utah',
    'VT': 'Vermont',
    'WY': 'Wyoming',
    'AK': 'Alaska',
    'MP': 'Northern Mariana Islands',
    'PR': 'Puerto Rico',
    'VI': 'Virgin Islands',
    'DC': 'District of Columbia',
    'RI': 'Rhode Island',
    'AS': 'American Samoa'
}

# %%
df_all['State Name'] = df_all['State Code'].map(state_name_mapping)

# %%
# put state name in the first column   
cols = df_all.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_all = df_all[cols]

# %%
df_all
# Out:
#           State Name State Code  Year  Total Deaths  No. Injured  \
# 1485         Alabama         AL  2019          56.0        114.0
# 1486        Arkansas         AR  2019          13.0         12.0
# 1487      California         CA  2019          76.0         14.0
# 1488        Colorado         CO  2019          27.0         57.0
# 1489     Connecticut         CT  2019           2.0         12.0
# ...              ...        ...   ...           ...          ...
# 2573          Oregon         OR  2023           NaN          NaN
# 2574    Rhode Island         RI  2023           NaN          NaN
# 2575  South Carolina         SC  2023           NaN          NaN
# 2576    South Dakota         SD  2023           NaN          NaN
# 2577         Vermont         VT  2023           NaN          NaN
#
#       Total Damage ('000 US$)  Total Disasters  \
# 1485                2925000.0             15.0
# 1486                4500000.0             39.0
# ...

# %%
df_all.fillna(0, inplace=True)
# Save the data to a csv file
df_all.to_csv('data_since_2019.csv', index=False)

# %%
df_all
# Out:
#           State Name State Code  Year  Total Deaths  No. Injured  \
# 1485         Alabama         AL  2019          56.0        114.0
# 1486        Arkansas         AR  2019          13.0         12.0
# 1487      California         CA  2019          76.0         14.0
# 1488        Colorado         CO  2019          27.0         57.0
# 1489     Connecticut         CT  2019           2.0         12.0
# ...              ...        ...   ...           ...          ...
# 2573          Oregon         OR  2023           0.0          0.0
# 2574    Rhode Island         RI  2023           0.0          0.0
# 2575  South Carolina         SC  2023           0.0          0.0
# 2576    South Dakota         SD  2023           0.0          0.0
# 2577         Vermont         VT  2023           0.0          0.0
#
#       Total Damage ('000 US$)  Total Disasters  \
# 1485                2925000.0             15.0
# 1486                4500000.0             39.0
# ...

# %%
# df_all_2019 = df_all[df_all['Year'] == 2019]
# df_all_2020 = df_all[df_all['Year'] == 2020]
# df_all_2021 = df_all[df_all['Year'] == 2021]
# df_all_2022 = df_all[df_all['Year'] == 2022]
# df_all_2023 = df_all[df_all['Year'] == 2023]
